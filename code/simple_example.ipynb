# %% [markdown]
# Welcome to the SENSS Training Event. Let's see if this is working.

# %%
# put a calculation
3 + 3
# Out:
# 6

# %% [markdown]
# Let's try to calculate a time until some date.
# We need to know today.

# %%
from datetime import date

today = date.today()
print(today)
# Out:
# 2026-05-18

# %%
my_date = date(2026, 12, 25)
print(my_date)
# Out:
# 2026-12-25

# %%
days_until = (my_date - today)
print(days_until)
# Out:
# 221 days, 0:00:00
